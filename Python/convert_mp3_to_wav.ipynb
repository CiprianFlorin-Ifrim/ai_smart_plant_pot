# %%
import os

# Add the path to ffmpeg and ffprobe before importing pydub
ffmpeg_path = '/opt/homebrew/bin'  # Common path for Homebrew installations on Apple Silicon Macs
if os.path.exists(ffmpeg_path):
    os.environ["PATH"] += os.pathsep + ffmpeg_path

from pydub import AudioSegment

# %%
def convert_mp3_to_wav(source_folder, target_folder):
    """
    Convert all MP3 files in the source folder to WAV format in the target folder.
    """
    # Ensure the target folder exists
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)

    # List all files in the source folder
    for filename in os.listdir(source_folder):
        if filename.endswith('.mp3'):
            mp3_path = os.path.join(source_folder, filename)
            wav_path = os.path.join(target_folder, os.path.splitext(filename)[0] + '.wav')

            # Load the MP3 file
            audio = AudioSegment.from_mp3(mp3_path)

            # Convert to WAV and save
            audio.export(wav_path, format='wav')
            print(f"Converted '{filename}' to WAV format.")

# %%
source_folder = '/Users/ciprian/Desktop/how are you doing command/'
target_folder = '/Users/ciprian/Desktop/how are you doing command/wav_files/'

convert_mp3_to_wav(source_folder, target_folder)
# Out:
# Converted 'hayd_sample_96_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_35_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_4_noise.mp3' to WAV format.
# Converted 'hayd_sample_49_slower.mp3' to WAV format.
# Converted 'hayd_sample_16_noise.mp3' to WAV format.
# Converted 'hayd_sample_93_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_78_faster.mp3' to WAV format.
# Converted 'hayd_sample_45.mp3' to WAV format.
# Converted 'hayd_sample_9_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_46_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_51.mp3' to WAV format.
# Converted 'hayd_sample_79.mp3' to WAV format.
# Converted 'hayd_sample_22_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_7_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_5.mp3' to WAV format.
# Converted 'hayd_sample_86.mp3' to WAV format.
# Converted 'hayd_sample_92.mp3' to WAV format.
# Converted 'hayd_sample_84_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_78_noise.mp3' to WAV format.
# Converted 'hayd_sample_20_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_72_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_87_faster.mp3' to WAV format.
# Converted 'hayd_sample_81_slower.mp3' to WAV format.
# Converted 'hayd_sample_65_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_63_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_58_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_62_slower.mp3' to WAV format.
# Converted 'hayd_sample_31_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_90_noise.mp3' to WAV format.
# Converted 'hayd_sample_59_noise.mp3' to WAV format.
# Converted 'hayd_sample_55_slower.mp3' to WAV format.
# Converted 'hayd_sample_31_faster.mp3' to WAV format.
# Converted 'hayd_sample_41_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_37_slower.mp3' to WAV format.
# Converted 'hayd_sample_72_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_32_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_27_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_23_noise.mp3' to WAV format.
# Converted 'hayd_sample_53_faster.mp3' to WAV format.
# Converted 'hayd_sample_64_faster.mp3' to WAV format.
# Converted 'hayd_sample_56_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_93.mp3' to WAV format.
# Converted 'hayd_sample_87.mp3' to WAV format.
# Converted 'hayd_sample_87_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_14_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_37_noise.mp3' to WAV format.
# Converted 'hayd_sample_78.mp3' to WAV format.
# Converted 'hayd_sample_4.mp3' to WAV format.
# Converted 'hayd_sample_50.mp3' to WAV format.
# Converted 'hayd_sample_44.mp3' to WAV format.
# Converted 'hayd_sample_57_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_56_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_43_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_19_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_7_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_11_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_84_noise.mp3' to WAV format.
# Converted 'hayd_sample_2_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_43_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_59_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_9_noise.mp3' to WAV format.
# Converted 'hayd_sample_64_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_52.mp3' to WAV format.
# Converted 'hayd_sample_93_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_61_noise.mp3' to WAV format.
# Converted 'hayd_sample_46.mp3' to WAV format.
# Converted 'hayd_sample_6.mp3' to WAV format.
# Converted 'hayd_sample_59_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_91.mp3' to WAV format.
# Converted 'hayd_sample_85.mp3' to WAV format.
# Converted 'hayd_sample_73_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_75_faster.mp3' to WAV format.
# Converted 'hayd_sample_85_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_66_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_28_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_42_faster.mp3' to WAV format.
# Converted 'hayd_sample_26_slower.mp3' to WAV format.
# Converted 'hayd_sample_23_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_7_faster.mp3' to WAV format.
# Converted 'hayd_sample_8_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_11_slower.mp3' to WAV format.
# Converted 'hayd_sample_75_noise.mp3' to WAV format.
# Converted 'hayd_sample_92_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_17_faster.mp3' to WAV format.
# Converted 'hayd_sample_20_faster.mp3' to WAV format.
# Converted 'hayd_sample_28_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_1_slower.mp3' to WAV format.
# Converted 'hayd_sample_25_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_34_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_44_slower.mp3' to WAV format.
# Converted 'hayd_sample_73_slower.mp3' to WAV format.
# Converted 'hayd_sample_77_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_39_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_10_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_20_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_35_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_6_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_90_slower.mp3' to WAV format.
# Converted 'hayd_sample_54_noise.mp3' to WAV format.
# Converted 'hayd_sample_96_faster.mp3' to WAV format.
# Converted 'hayd_sample_34_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_57_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_52_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_84.mp3' to WAV format.
# Converted 'hayd_sample_90.mp3' to WAV format.
# Converted 'hayd_sample_7.mp3' to WAV format.
# Converted 'hayd_sample_44_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_51_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_69_faster.mp3' to WAV format.
# Converted 'hayd_sample_47.mp3' to WAV format.
# Converted 'hayd_sample_53.mp3' to WAV format.
# Converted 'hayd_sample_82_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_11_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_40_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_40_noise.mp3' to WAV format.
# Converted 'hayd_sample_89_noise.mp3' to WAV format.
# Converted 'hayd_sample_58_slower.mp3' to WAV format.
# Converted 'hayd_sample_97_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_25_noise.mp3' to WAV format.
# Converted 'hayd_sample_14_slower.mp3' to WAV format.
# Converted 'hayd_sample_23_slower.mp3' to WAV format.
# Converted 'hayd_sample_2_faster.mp3' to WAV format.
# Converted 'hayd_sample_47_faster.mp3' to WAV format.
# Converted 'hayd_sample_70_faster.mp3' to WAV format.
# Converted 'hayd_sample_47_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_76_slower.mp3' to WAV format.
# Converted 'hayd_sample_3.mp3' to WAV format.
# Converted 'hayd_sample_6_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_34_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_57.mp3' to WAV format.
# Converted 'hayd_sample_21_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_47_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_96_noise.mp3' to WAV format.
# Converted 'hayd_sample_43.mp3' to WAV format.
# Converted 'hayd_sample_41_slower.mp3' to WAV format.
# Converted 'hayd_sample_25_faster.mp3' to WAV format.
# Converted 'hayd_sample_4_slower.mp3' to WAV format.
# Converted 'hayd_sample_94.mp3' to WAV format.
# Converted 'hayd_sample_12_faster.mp3' to WAV format.
# Converted 'hayd_sample_80.mp3' to WAV format.
# Converted 'hayd_sample_50_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_21_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_82_noise.mp3' to WAV format.
# Converted 'hayd_sample_89_slower.mp3' to WAV format.
# Converted 'hayd_sample_62_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_1_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_50_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_45_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_17_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_31_noise.mp3' to WAV format.
# Converted 'hayd_sample_30_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_33_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_58_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_95_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_73_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_2_noise.mp3' to WAV format.
# Converted 'hayd_sample_39_faster.mp3' to WAV format.
# Converted 'hayd_sample_24_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_19_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_82_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_10_noise.mp3' to WAV format.
# Converted 'hayd_sample_74_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_81.mp3' to WAV format.
# Converted 'hayd_sample_15_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_86_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_95_slower.mp3' to WAV format.
# Converted 'hayd_sample_95.mp3' to WAV format.
# Converted 'hayd_sample_49_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_42.mp3' to WAV format.
# Converted 'hayd_sample_29_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_56.mp3' to WAV format.
# Converted 'hayd_sample_2.mp3' to WAV format.
# Converted 'hayd_sample_18_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_100_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_63_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_56_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_93_faster.mp3' to WAV format.
# Converted 'hayd_sample_82_faster.mp3' to WAV format.
# Converted 'hayd_sample_42_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_3_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_16_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_26_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_33_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_28_noise.mp3' to WAV format.
# Converted 'hayd_sample_68.mp3' to WAV format.
# Converted 'hayd_sample_40.mp3' to WAV format.
# Converted 'hayd_sample_54.mp3' to WAV format.
# Converted 'hayd_sample_92_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_52_noise.mp3' to WAV format.
# Converted 'hayd_sample_84_slower.mp3' to WAV format.
# Converted 'hayd_sample_83.mp3' to WAV format.
# Converted 'hayd_sample_97.mp3' to WAV format.
# Converted 'hayd_sample_51_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_29_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_67_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_46_noise.mp3' to WAV format.
# Converted 'hayd_sample_42_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_57_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_28_faster.mp3' to WAV format.
# Converted 'hayd_sample_9_slower.mp3' to WAV format.
# Converted 'hayd_sample_24_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_19_slower.mp3' to WAV format.
# Converted 'hayd_sample_46_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_38_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_76_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_67_noise.mp3' to WAV format.
# Converted 'hayd_sample_62_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_35_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_98_slower.mp3' to WAV format.
# Converted 'hayd_sample_48_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_75_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_96.mp3' to WAV format.
# Converted 'hayd_sample_83_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_53_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_82.mp3' to WAV format.
# Converted 'hayd_sample_18_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_34_faster.mp3' to WAV format.
# Converted 'hayd_sample_55.mp3' to WAV format.
# Converted 'hayd_sample_50_slower.mp3' to WAV format.
# Converted 'hayd_sample_41.mp3' to WAV format.
# Converted 'hayd_sample_25_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_69.mp3' to WAV format.
# Converted 'hayd_sample_67_slower.mp3' to WAV format.
# Converted 'hayd_sample_1.mp3' to WAV format.
# Converted 'hayd_sample_61_faster.mp3' to WAV format.
# Converted 'hayd_sample_94_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_10_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_83_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_56_faster.mp3' to WAV format.
# Converted 'hayd_sample_32_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_32_slower.mp3' to WAV format.
# Converted 'hayd_sample_73_noise.mp3' to WAV format.
# Converted 'hayd_sample_57_slower.mp3' to WAV format.
# Converted 'hayd_sample_79_noise.mp3' to WAV format.
# Converted 'hayd_sample_60_slower.mp3' to WAV format.
# Converted 'hayd_sample_94_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_8_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_49_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_33_faster.mp3' to WAV format.
# Converted 'hayd_sample_26.mp3' to WAV format.
# Converted 'hayd_sample_32.mp3' to WAV format.
# Converted 'hayd_sample_35_slower.mp3' to WAV format.
# Converted 'hayd_sample_40_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_55_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_99_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_66_faster.mp3' to WAV format.
# Converted 'hayd_sample_5_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_16_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_51_faster.mp3' to WAV format.
# Converted 'hayd_sample_44_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_5_noise.mp3' to WAV format.
# Converted 'hayd_sample_99_faster.mp3' to WAV format.
# Converted 'hayd_sample_46_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_22_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_17_noise.mp3' to WAV format.
# Converted 'hayd_sample_24_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_31_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_51_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_61_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_18_faster.mp3' to WAV format.
# Converted 'hayd_sample_75_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_36_noise.mp3' to WAV format.
# Converted 'hayd_sample_48_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_39_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_33_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_100_slower.mp3' to WAV format.
# Converted 'hayd_sample_62_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_85_noise.mp3' to WAV format.
# Converted 'hayd_sample_70_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_8_faster.mp3' to WAV format.
# Converted 'hayd_sample_29_slower.mp3' to WAV format.
# Converted 'hayd_sample_32_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_91_noise.mp3' to WAV format.
# Converted 'hayd_sample_58_noise.mp3' to WAV format.
# Converted 'hayd_sample_16_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_85_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_94_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_85_faster.mp3' to WAV format.
# Converted 'hayd_sample_33.mp3' to WAV format.
# Converted 'hayd_sample_58_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_48_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_27.mp3' to WAV format.
# Converted 'hayd_sample_25_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_22_noise.mp3' to WAV format.
# Converted 'hayd_sample_83_slower.mp3' to WAV format.
# Converted 'hayd_sample_88_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_18_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_83_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_55_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_50_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_92_slower.mp3' to WAV format.
# Converted 'hayd_sample_74_noise.mp3' to WAV format.
# Converted 'hayd_sample_41_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_52_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_47_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_31.mp3' to WAV format.
# Converted 'hayd_sample_25.mp3' to WAV format.
# Converted 'hayd_sample_19.mp3' to WAV format.
# Converted 'hayd_sample_94_faster.mp3' to WAV format.
# Converted 'hayd_sample_47_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_91_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_17_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_38_slower.mp3' to WAV format.
# Converted 'hayd_sample_8_noise.mp3' to WAV format.
# Converted 'hayd_sample_1_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_64_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_36_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_23_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_60_noise.mp3' to WAV format.
# Converted 'hayd_sample_27_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_69_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_82_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_19_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_75_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_24_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_41_noise.mp3' to WAV format.
# Converted 'hayd_sample_88_noise.mp3' to WAV format.
# Converted 'hayd_sample_95_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_36_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_88_faster.mp3' to WAV format.
# Converted 'hayd_sample_33_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_78_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_40_faster.mp3' to WAV format.
# Converted 'hayd_sample_77_faster.mp3' to WAV format.
# Converted 'hayd_sample_55_noise.mp3' to WAV format.
# Converted 'hayd_sample_18.mp3' to WAV format.
# Converted 'hayd_sample_13_slower.mp3' to WAV format.
# Converted 'hayd_sample_63_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_50_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_5_faster.mp3' to WAV format.
# Converted 'hayd_sample_24.mp3' to WAV format.
# Converted 'hayd_sample_24_slower.mp3' to WAV format.
# Converted 'hayd_sample_30.mp3' to WAV format.
# Converted 'hayd_sample_3_slower.mp3' to WAV format.
# Converted 'hayd_sample_49_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_22_faster.mp3' to WAV format.
# Converted 'hayd_sample_15_faster.mp3' to WAV format.
# Converted 'hayd_sample_74_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_71_slower.mp3' to WAV format.
# Converted 'hayd_sample_46_slower.mp3' to WAV format.
# Converted 'hayd_sample_13_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_80_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_59_faster.mp3' to WAV format.
# Converted 'hayd_sample_73_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_48_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_9_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_83_noise.mp3' to WAV format.
# Converted 'hayd_sample_95_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_34.mp3' to WAV format.
# Converted 'hayd_sample_64_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_20.mp3' to WAV format.
# Converted 'hayd_sample_30_noise.mp3' to WAV format.
# Converted 'hayd_sample_45_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_68_slower.mp3' to WAV format.
# Converted 'hayd_sample_4_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_59_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_98_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_34_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_97_slower.mp3' to WAV format.
# Converted 'hayd_sample_24_noise.mp3' to WAV format.
# Converted 'hayd_sample_92_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_23_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_23_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_97_noise.mp3' to WAV format.
# Converted 'hayd_sample_8_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_85_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_91_faster.mp3' to WAV format.
# Converted 'hayd_sample_60_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_21_slower.mp3' to WAV format.
# Converted 'hayd_sample_16_slower.mp3' to WAV format.
# Converted 'hayd_sample_32_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_72_faster.mp3' to WAV format.
# Converted 'hayd_sample_45_faster.mp3' to WAV format.
# Converted 'hayd_sample_43_slower.mp3' to WAV format.
# Converted 'hayd_sample_46_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_53_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_6_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_74_slower.mp3' to WAV format.
# Converted 'hayd_sample_10_faster.mp3' to WAV format.
# Converted 'hayd_sample_6_slower.mp3' to WAV format.
# Converted 'hayd_sample_10_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_71_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_27_faster.mp3' to WAV format.
# Converted 'hayd_sample_40_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_21.mp3' to WAV format.
# Converted 'hayd_sample_35.mp3' to WAV format.
# Converted 'hayd_sample_59_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_84_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_17_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_22_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_37_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_3_noise.mp3' to WAV format.
# Converted 'hayd_sample_11_noise.mp3' to WAV format.
# Converted 'hayd_sample_54_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_57_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_89_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_47_noise.mp3' to WAV format.
# Converted 'hayd_sample_84_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_9_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_1_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_40_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_22_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_38_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_23.mp3' to WAV format.
# Converted 'hayd_sample_93_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_37.mp3' to WAV format.
# Converted 'hayd_sample_90_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_35_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_58_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_36_faster.mp3' to WAV format.
# Converted 'hayd_sample_65_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_29_noise.mp3' to WAV format.
# Converted 'hayd_sample_65_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_65_slower.mp3' to WAV format.
# Converted 'hayd_sample_52_slower.mp3' to WAV format.
# Converted 'hayd_sample_54_faster.mp3' to WAV format.
# Converted 'hayd_sample_49_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_63_faster.mp3' to WAV format.
# Converted 'hayd_sample_68_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_72_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_53_noise.mp3' to WAV format.
# Converted 'hayd_sample_26_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_30_slower.mp3' to WAV format.
# Converted 'hayd_sample_56_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_80_faster.mp3' to WAV format.
# Converted 'hayd_sample_74_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_54_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_41_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_41_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_86_slower.mp3' to WAV format.
# Converted 'hayd_sample_79_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_72_noise.mp3' to WAV format.
# Converted 'hayd_sample_37_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_66_noise.mp3' to WAV format.
# Converted 'hayd_sample_11_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_79_slower.mp3' to WAV format.
# Converted 'hayd_sample_36.mp3' to WAV format.
# Converted 'hayd_sample_22.mp3' to WAV format.
# Converted 'hayd_sample_30_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_25_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_7_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_51_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_81_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_12_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_48_faster.mp3' to WAV format.
# Converted 'hayd_sample_22_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_19_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_92_noise.mp3' to WAV format.
# Converted 'hayd_sample_77_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_88_slower.mp3' to WAV format.
# Converted 'hayd_sample_61_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_6_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_13.mp3' to WAV format.
# Converted 'hayd_sample_100.mp3' to WAV format.
# Converted 'hayd_sample_97_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_82_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_60_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_21_noise.mp3' to WAV format.
# Converted 'hayd_sample_15_slower.mp3' to WAV format.
# Converted 'hayd_sample_96_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_8_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_35_noise.mp3' to WAV format.
# Converted 'hayd_sample_94_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_3_faster.mp3' to WAV format.
# Converted 'hayd_sample_49_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_68_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_22_slower.mp3' to WAV format.
# Converted 'hayd_sample_46_faster.mp3' to WAV format.
# Converted 'hayd_sample_30_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_71_faster.mp3' to WAV format.
# Converted 'hayd_sample_5_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_99_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_77_slower.mp3' to WAV format.
# Converted 'hayd_sample_81_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_40_slower.mp3' to WAV format.
# Converted 'hayd_sample_86_noise.mp3' to WAV format.
# Converted 'hayd_sample_44_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_27_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_5_slower.mp3' to WAV format.
# Converted 'hayd_sample_24_faster.mp3' to WAV format.
# Converted 'hayd_sample_13_faster.mp3' to WAV format.
# Converted 'hayd_sample_14_noise.mp3' to WAV format.
# Converted 'hayd_sample_94_slower.mp3' to WAV format.
# Converted 'hayd_sample_85_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_16_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_98_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_58_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_6_noise.mp3' to WAV format.
# Converted 'hayd_sample_88_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_14_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_55_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_60_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_75_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_2_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_29_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_92_faster.mp3' to WAV format.
# Converted 'hayd_sample_44_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_33_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_100_noise.mp3' to WAV format.
# Converted 'hayd_sample_79_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_12.mp3' to WAV format.
# Converted 'hayd_sample_70_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_53_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_38_faster.mp3' to WAV format.
# Converted 'hayd_sample_11_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_85_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_90_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_100_faster.mp3' to WAV format.
# Converted 'hayd_sample_56_noise.mp3' to WAV format.
# Converted 'hayd_sample_26_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_64_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_8_slower.mp3' to WAV format.
# Converted 'hayd_sample_29_faster.mp3' to WAV format.
# Converted 'hayd_sample_100_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_80_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_1_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_18_slower.mp3' to WAV format.
# Converted 'hayd_sample_10.mp3' to WAV format.
# Converted 'hayd_sample_27_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_31_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_38.mp3' to WAV format.
# Converted 'hayd_sample_69_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_97_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_41_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_61_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_83_faster.mp3' to WAV format.
# Converted 'hayd_sample_38_noise.mp3' to WAV format.
# Converted 'hayd_sample_76_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_91_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_42_noise.mp3' to WAV format.
# Converted 'hayd_sample_85_slower.mp3' to WAV format.
# Converted 'hayd_sample_50_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_72_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_67_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_35_faster.mp3' to WAV format.
# Converted 'hayd_sample_51_slower.mp3' to WAV format.
# Converted 'hayd_sample_52_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_19_noise.mp3' to WAV format.
# Converted 'hayd_sample_66_slower.mp3' to WAV format.
# Converted 'hayd_sample_60_faster.mp3' to WAV format.
# Converted 'hayd_sample_57_faster.mp3' to WAV format.
# Converted 'hayd_sample_80_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_13_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_78_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_63_noise.mp3' to WAV format.
# Converted 'hayd_sample_33_slower.mp3' to WAV format.
# Converted 'hayd_sample_45_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_28_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_3_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_77_noise.mp3' to WAV format.
# Converted 'hayd_sample_75_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_16_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_39.mp3' to WAV format.
# Converted 'hayd_sample_15_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_11.mp3' to WAV format.
# Converted 'hayd_sample_9_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_99_slower.mp3' to WAV format.
# Converted 'hayd_sample_36_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_78_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_99_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_98_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_68_noise.mp3' to WAV format.
# Converted 'hayd_sample_23_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_86_faster.mp3' to WAV format.
# Converted 'hayd_sample_38_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_29.mp3' to WAV format.
# Converted 'hayd_sample_80_slower.mp3' to WAV format.
# Converted 'hayd_sample_15.mp3' to WAV format.
# Converted 'hayd_sample_12_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_89_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_12_noise.mp3' to WAV format.
# Converted 'hayd_sample_60_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_66_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_73_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_4_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_99_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_48_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_42_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_95_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_9_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_48_slower.mp3' to WAV format.
# Converted 'hayd_sample_8_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_45_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_55_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_79_faster.mp3' to WAV format.
# Converted 'hayd_sample_98_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_4_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_17_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_68_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_59_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_17_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_84_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_27_noise.mp3' to WAV format.
# Converted 'hayd_sample_71_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_54_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_89_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_91_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_84_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_66_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_94_noise.mp3' to WAV format.
# Converted 'hayd_sample_80_noise.mp3' to WAV format.
# Converted 'hayd_sample_49_noise.mp3' to WAV format.
# Converted 'hayd_sample_90_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_32_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_63_slower.mp3' to WAV format.
# Converted 'hayd_sample_54_slower.mp3' to WAV format.
# Converted 'hayd_sample_36_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_14.mp3' to WAV format.
# Converted 'hayd_sample_30_faster.mp3' to WAV format.
# Converted 'hayd_sample_28.mp3' to WAV format.
# Converted 'hayd_sample_87_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_33_noise.mp3' to WAV format.
# Converted 'hayd_sample_71_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_36_slower.mp3' to WAV format.
# Converted 'hayd_sample_21_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_52_faster.mp3' to WAV format.
# Converted 'hayd_sample_65_faster.mp3' to WAV format.
# Converted 'hayd_sample_65_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_74_faster.mp3' to WAV format.
# Converted 'hayd_sample_43_faster.mp3' to WAV format.
# Converted 'hayd_sample_69_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_74_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_61_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_6_faster.mp3' to WAV format.
# Converted 'hayd_sample_27_slower.mp3' to WAV format.
# Converted 'hayd_sample_65_noise.mp3' to WAV format.
# Converted 'hayd_sample_54_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_10_slower.mp3' to WAV format.
# Converted 'hayd_sample_16_faster.mp3' to WAV format.
# Converted 'hayd_sample_68_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_26_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_16.mp3' to WAV format.
# Converted 'hayd_sample_21_faster.mp3' to WAV format.
# Converted 'hayd_sample_45_slower.mp3' to WAV format.
# Converted 'hayd_sample_72_slower.mp3' to WAV format.
# Converted 'hayd_sample_43_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_1_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_5_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_10_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_40_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_88_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_13_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_39_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_90_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_71_noise.mp3' to WAV format.
# Converted 'hayd_sample_83_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_96_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_51_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_20_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_86_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_7_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_68_faster.mp3' to WAV format.
# Converted 'hayd_sample_50_noise.mp3' to WAV format.
# Converted 'hayd_sample_99_noise.mp3' to WAV format.
# Converted 'hayd_sample_12_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_81_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_59_slower.mp3' to WAV format.
# Converted 'hayd_sample_37_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_18_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_91_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_74_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_67_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_17.mp3' to WAV format.
# Converted 'hayd_sample_44_noise.mp3' to WAV format.
# Converted 'hayd_sample_91_slower.mp3' to WAV format.
# Converted 'hayd_sample_79_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_70_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_97_faster.mp3' to WAV format.
# Converted 'hayd_sample_37_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_69_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_89_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_34_noise.mp3' to WAV format.
# Converted 'hayd_sample_43_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_96_slower.mp3' to WAV format.
# Converted 'hayd_sample_20_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_64.mp3' to WAV format.
# Converted 'hayd_sample_87_noise.mp3' to WAV format.
# Converted 'hayd_sample_70.mp3' to WAV format.
# Converted 'hayd_sample_58.mp3' to WAV format.
# Converted 'hayd_sample_54_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_90_faster.mp3' to WAV format.
# Converted 'hayd_sample_69_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_12_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_63_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_58_faster.mp3' to WAV format.
# Converted 'hayd_sample_39_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_96_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_93_noise.mp3' to WAV format.
# Converted 'hayd_sample_13_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_88_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_46_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_69_slower.mp3' to WAV format.
# Converted 'hayd_sample_20_noise.mp3' to WAV format.
# Converted 'hayd_sample_76_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_63_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_5_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_7_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_91_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_14_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_87_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_37_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_86_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_57_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_19_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_20_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_20_slower.mp3' to WAV format.
# Converted 'hayd_sample_1_faster.mp3' to WAV format.
# Converted 'hayd_sample_15_noise.mp3' to WAV format.
# Converted 'hayd_sample_17_slower.mp3' to WAV format.
# Converted 'hayd_sample_70_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_73_faster.mp3' to WAV format.
# Converted 'hayd_sample_7_noise.mp3' to WAV format.
# Converted 'hayd_sample_59.mp3' to WAV format.
# Converted 'hayd_sample_31_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_71.mp3' to WAV format.
# Converted 'hayd_sample_65.mp3' to WAV format.
# Converted 'hayd_sample_44_faster.mp3' to WAV format.
# Converted 'hayd_sample_42_slower.mp3' to WAV format.
# Converted 'hayd_sample_75_slower.mp3' to WAV format.
# Converted 'hayd_sample_5_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_81_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_94_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_11_faster.mp3' to WAV format.
# Converted 'hayd_sample_67_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_26_faster.mp3' to WAV format.
# Converted 'hayd_sample_72_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_7_slower.mp3' to WAV format.
# Converted 'hayd_sample_37_faster.mp3' to WAV format.
# Converted 'hayd_sample_4_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_15_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_64_slower.mp3' to WAV format.
# Converted 'hayd_sample_66_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_39_noise.mp3' to WAV format.
# Converted 'hayd_sample_89_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_28_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_53_slower.mp3' to WAV format.
# Converted 'hayd_sample_12_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_73.mp3' to WAV format.
# Converted 'hayd_sample_67.mp3' to WAV format.
# Converted 'hayd_sample_55_faster.mp3' to WAV format.
# Converted 'hayd_sample_62_faster.mp3' to WAV format.
# Converted 'hayd_sample_38_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_31_slower.mp3' to WAV format.
# Converted 'hayd_sample_25_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_43_noise.mp3' to WAV format.
# Converted 'hayd_sample_98.mp3' to WAV format.
# Converted 'hayd_sample_68_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_57_noise.mp3' to WAV format.
# Converted 'hayd_sample_64_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_71_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_55_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_2_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_43_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_42_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_93_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_76_noise.mp3' to WAV format.
# Converted 'hayd_sample_78_slower.mp3' to WAV format.
# Converted 'hayd_sample_66_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_52_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_71_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_11_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_82_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_49_faster.mp3' to WAV format.
# Converted 'hayd_sample_79_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_99.mp3' to WAV format.
# Converted 'hayd_sample_21_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_81_faster.mp3' to WAV format.
# Converted 'hayd_sample_93_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_86_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_77_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_87_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_2_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_18_noise.mp3' to WAV format.
# Converted 'hayd_sample_39_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_66.mp3' to WAV format.
# Converted 'hayd_sample_72.mp3' to WAV format.
# Converted 'hayd_sample_36_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_87_slower.mp3' to WAV format.
# Converted 'hayd_sample_90_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_34_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_62_noise.mp3' to WAV format.
# Converted 'hayd_sample_78_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_97_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_98_faster.mp3' to WAV format.
# Converted 'hayd_sample_21_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_31_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_76.mp3' to WAV format.
# Converted 'hayd_sample_62.mp3' to WAV format.
# Converted 'hayd_sample_100_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_80_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_62_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_89.mp3' to WAV format.
# Converted 'hayd_sample_26_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_56_slower.mp3' to WAV format.
# Converted 'hayd_sample_61_slower.mp3' to WAV format.
# Converted 'hayd_sample_69_noise.mp3' to WAV format.
# Converted 'hayd_sample_76_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_97_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_32_faster.mp3' to WAV format.
# Converted 'hayd_sample_34_slower.mp3' to WAV format.
# Converted 'hayd_sample_13_noise.mp3' to WAV format.
# Converted 'hayd_sample_3_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_6_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_67_faster.mp3' to WAV format.
# Converted 'hayd_sample_61_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_87_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_92_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_47_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_50_faster.mp3' to WAV format.
# Converted 'hayd_sample_1_noise.mp3' to WAV format.
# Converted 'hayd_sample_81_noise.mp3' to WAV format.
# Converted 'hayd_sample_45_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_48_noise.mp3' to WAV format.
# Converted 'hayd_sample_84_faster.mp3' to WAV format.
# Converted 'hayd_sample_86_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_15_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_78_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_32_noise.mp3' to WAV format.
# Converted 'hayd_sample_82_slower.mp3' to WAV format.
# Converted 'hayd_sample_52_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_100_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_18_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_14_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_56_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_99_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_88.mp3' to WAV format.
# Converted 'hayd_sample_19_faster.mp3' to WAV format.
# Converted 'hayd_sample_63.mp3' to WAV format.
# Converted 'hayd_sample_77.mp3' to WAV format.
# Converted 'hayd_sample_30_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_26_noise.mp3' to WAV format.
# Converted 'hayd_sample_15_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_28_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_73_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_95_noise.mp3' to WAV format.
# Converted 'hayd_sample_28_slower.mp3' to WAV format.
# Converted 'hayd_sample_70_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_65_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_3_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_9_faster.mp3' to WAV format.
# Converted 'hayd_sample_39_slower.mp3' to WAV format.
# Converted 'hayd_sample_60_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_29_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_67_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_49.mp3' to WAV format.
# Converted 'hayd_sample_61.mp3' to WAV format.
# Converted 'hayd_sample_75.mp3' to WAV format.
# Converted 'hayd_sample_77_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_70_noise.mp3' to WAV format.
# Converted 'hayd_sample_9.mp3' to WAV format.
# Converted 'hayd_sample_24_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_27_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_95_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_80_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_64_noise.mp3' to WAV format.
# Converted 'hayd_sample_93_slower.mp3' to WAV format.
# Converted 'hayd_sample_42_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_81_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_4_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_3_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_30_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_95_faster.mp3' to WAV format.
# Converted 'hayd_sample_96_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_92_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_2_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_13_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_41_faster.mp3' to WAV format.
# Converted 'hayd_sample_76_faster.mp3' to WAV format.
# Converted 'hayd_sample_29_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_53_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_12_slower.mp3' to WAV format.
# Converted 'hayd_sample_45_noise.mp3' to WAV format.
# Converted 'hayd_sample_25_slower.mp3' to WAV format.
# Converted 'hayd_sample_100_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_4_faster.mp3' to WAV format.
# Converted 'hayd_sample_14_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_23_faster.mp3' to WAV format.
# Converted 'hayd_sample_2_slower.mp3' to WAV format.
# Converted 'hayd_sample_14_faster.mp3' to WAV format.
# Converted 'hayd_sample_70_slower.mp3' to WAV format.
# Converted 'hayd_sample_88_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_83_silence_begin.mp3' to WAV format.
# Converted 'hayd_sample_10_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_47_slower.mp3' to WAV format.
# Converted 'hayd_sample_98_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_62_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_77_low_volume.mp3' to WAV format.
# Converted 'hayd_sample_74.mp3' to WAV format.
# Converted 'hayd_sample_8.mp3' to WAV format.
# Converted 'hayd_sample_53_high_volume.mp3' to WAV format.
# Converted 'hayd_sample_38_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_60.mp3' to WAV format.
# Converted 'hayd_sample_48.mp3' to WAV format.
# Converted 'hayd_sample_76_parts_missing.mp3' to WAV format.
# Converted 'hayd_sample_79_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_51_noise.mp3' to WAV format.
# Converted 'hayd_sample_98_noise.mp3' to WAV format.
# Converted 'hayd_sample_89_faster.mp3' to WAV format.
# Converted 'hayd_sample_44_silence_end.mp3' to WAV format.
# Converted 'hayd_sample_35_silence_begin.mp3' to WAV format.
