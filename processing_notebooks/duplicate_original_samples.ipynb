# %%
#-------------------------------------------------------------------------------------JUPYTER NOTEBOOK SETTINGS-------------------------------------------------------------------------------------
from IPython.core.display import display, HTML                                    
display(HTML("<style>.container { width:100% !important; }</style>"))  
import IPython.display as display
# Out:
# /var/folders/ry/454yhlzx6hd15j7rjv4th0lw0000gn/T/ipykernel_72961/4123656545.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
import os
import shutil
import re

# %%
def copy_battery_samples(source_folder, destination_folder):
    # Ensure the destination folder exists
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)
        print(f"Created destination folder: {destination_folder}")
    
    # Compile the regular expression pattern
    pattern = re.compile(r'^battery_sample_\d+\.wav$')
    
    # Iterate through files in the source folder
    for filename in os.listdir(source_folder):
        # Check if the filename matches the pattern
        if pattern.match(filename):
            # Construct full file paths
            source_path = os.path.join(source_folder, filename)
            destination_path = os.path.join(destination_folder, filename)
            
            # Copy the file
            shutil.copy2(source_path, destination_path)
            print(f'Copied {filename} to {destination_folder}')
            
if __name__ == "__main__":
    # Define your source and destination folders
    source_folder = "/Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 3/male/battery"
    destination_folder = "/Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery"
    
    # Call the function to copy the files
    copy_battery_samples(source_folder, destination_folder)
# Out:
# Copied battery_sample_190.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_49.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_184.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_75.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_61.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_153.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# Copied battery_sample_147.wav to /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/male/battery
# ...
