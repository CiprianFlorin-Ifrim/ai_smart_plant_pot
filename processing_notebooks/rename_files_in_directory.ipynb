# %%
import os

def rename_files_in_directory(directory_path, prefix):
    try:
        # Check if the given path exists
        if not os.path.exists(directory_path):
            print(f"The directory {directory_path} does not exist.")
            return
        
        # Get a list of all files in the directory, excluding .DS_Store
        files = os.listdir(directory_path)
        files = [f for f in files if os.path.isfile(os.path.join(directory_path, f)) and f != ".DS_Store"]
        
        # Sort files to maintain order
        files.sort()
        
        # Rename each file
        for i, filename in enumerate(files, start=1):
            # Extract the file extension
            file_extension = os.path.splitext(filename)[1]
            
            # Create the new filename
            new_filename = f"{prefix}{i}{file_extension}"
            
            # Construct the full file paths
            old_file_path = os.path.join(directory_path, filename)
            new_file_path = os.path.join(directory_path, new_filename)
            
            # Rename the file
            os.rename(old_file_path, new_file_path)
            print(f"Renamed: {filename} -> {new_filename}")
            
        print("All files have been renamed successfully.")
    
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    # Example usage
    directory_path = input("Enter the directory path: ")
    prefix = input("Enter the prefix for renaming files: ")
    rename_files_in_directory(directory_path, prefix)
# Out:
# Enter the directory path: /Users/ciprian/Desktop/Projects/Smart Plant Pot/Audio/Voice Recognition/Prototype 4/noise/silence
# Enter the prefix for renaming files: silence_sample_
# Renamed: segment_1.wav -> silence_sample_1.wav
# Renamed: segment_10.wav -> silence_sample_2.wav
# Renamed: segment_100.wav -> silence_sample_3.wav
# Renamed: segment_1000.wav -> silence_sample_4.wav
# Renamed: segment_1000_faster.wav -> silence_sample_5.wav
# Renamed: segment_1000_high_volume.wav -> silence_sample_6.wav
# Renamed: segment_1000_low_volume.wav -> silence_sample_7.wav
# Renamed: segment_1000_noise.wav -> silence_sample_8.wav
# Renamed: segment_1000_parts_missing.wav -> silence_sample_9.wav
# Renamed: segment_1000_removed_end_200ms.wav -> silence_sample_10.wav
# Renamed: segment_1000_removed_start_200ms.wav -> silence_sample_11.wav
# Renamed: segment_1000_silence_begin.wav -> silence_sample_12.wav
# Renamed: segment_1000_silence_end.wav -> silence_sample_13.wav
# ...
